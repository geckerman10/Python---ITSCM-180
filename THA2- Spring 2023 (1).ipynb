# %% [markdown]
# ## Problem 1
#
# A project manager needs a python program using which he can enter the expenses related to the two projects that he manages (P1 & P2) from the paper invoices and at the end receives the total expenditute, as well as average per-invoice expense for each project separately.
#
# For each invoice, he wants to enter a single input containing the project ID (P1 or P2) and the expense amount in USD, separated by a semicolon (e.g., P1;128.55). Once he is done with all the invoices he wants to enter the word 'done' and immediately see the desired outputs on the screen.
#
# Example:
# <br>Enter the project ID and expense for the current invoice: p1;1055.11
# <br>Enter the project ID and expense for the current invoice: P2;779.09
# <br>Enter the project ID and expense for the current invoice: p2;110
# <br>Enter the project ID and expense for the current invoice: P1;507
# <br>Enter the project ID and expense for the current invoice: p2;1366.40
# <br>Enter the project ID and expense for the current invoice: done
#
# <br>Total expenditure on Project 1 is 1562.11 . That is 781.06 per invoice on average
# <br>Total expenditure on Project 2 is 2255.49 . That is 751.83 per invoice on average

# %%
#create a loop to read the values
p1expenditure=0
p2expenditure=0
p1count=0
p2count=0
while True:
    #get value and extract info
    expense=input("Enter the project ID and expense for the current invoice:")
    expense=expense.lower()
    project=expense[0:2]
    #end the loop when done is written
    if expense=="done":
        break
    #look at each project and create a total for expenditure and the count of items
    elif project=="p1":
        money=float(expense[3:])
        p1expenditure=p1expenditure+money
        p1count+=1
    elif project=='p2':
        money=float(expense[3:])
        p2expenditure=p2expenditure+money
        p2count+=1
#calculate average spending and pring results
p1average=p1expenditure/p1count
p2average=p2expenditure/p2count
print('Total expenditure on Project 1 is',round(p1expenditure,2),'That is',round(p1average,2),'per invoice on average')
print('Total expenditure on Project 2 is',round(p2expenditure,2),'That is',round(p2average,2),'per invoice on average')
# Out:
# Enter the project ID and expense for the current invoice: p1:1055.11
# Enter the project ID and expense for the current invoice: P2;779.09
# Enter the project ID and expense for the current invoice: p2;110
# Enter the project ID and expense for the current invoice: P1;507
# Enter the project ID and expense for the current invoice: p2;1366.40
# Enter the project ID and expense for the current invoice: done
# Total expenditure on Project 1 is 1562.11 That is 781.05 per invoice on average
# Total expenditure on Project 2 is 2255.49 That is 751.83 per invoice on average

# %% [markdown]
# ## Problem 2.1
#
# Download the text file Tweets.txt from the URL provided below and save it in your python directory folder:
# https://bit.ly/360oAwY
# <br><br>The file includes 4993 tweets containing the keyword 'election'. Each tweet is represented in a separate line.
# <br>Write a program to open the file and read through its lines, then only if a tweet includes a hashtag (a term beginning by the # character) extracts the hashtag term and prints it out. For simplicity, let's assume that each tweet can include only 1 hashtag (if any), so in case of multiple hashtags in a tweet we are only interested in extracting the first one from left.
#
# <br>**Note**: since some tweets may include irregular characters(e.g., emojis), use the term **encoding="utf-8"** as the third argument in the **open** function, separated by comma from the text file name and opening mode. Otherwise you may get error.

# %%
#open file
handle=open('Tweets.txt','r',encoding="utf-8")
#read each line and find lines with http://
for line in handle:
    if '#' in line:
        #find index number for each character and print between them
        beg=line.find('#')
        end=line.find(' ',beg)
        print(line[beg:end])
# Out:
# #COVID19
# #CA25
# #nvleg's
# #BluestarZone
# #MAGA
# #
# #COVID19
# #44
# #justiceforgeneralscholarship
# #democracy
# #VoteByMail
# #OhioPrimary
# #Yuju
# #ThanksObama"
# #MarthaMcSulliedMyOath,
# #Democrat
# #BallotHarvesting.
# #Yuju
# #QAnon
# #theSoulofAmerica.
# #BallotHarvesting.
# #WuhanVirus
# #coronavirus
# #COVID19
# #coronavirus
# #coronavirus
# #ReopenAmerica
# #SouthCarolina
# #????
# #TrumpPenceOutNow#OutNowhttps://t.co/64IDzcG0nf#GeneralStrike#GeneralStrike2020
# #ThanksObama
# #ThanksObama"
# #Roblox
# #canada
# #coronavirus
# #BTS
# #coronavirus
# #JISUNG
# #VoteByMail
# #BhashanIsRation"
# #BallotHarvesting.
# #MLA
# #BallotHarvesting.
# #LNPCrimeFamily
# #StopTheSteal
# #Democrat
# #NoToMailVoting
# #DemCast
# #NewsandPolitics
# #QAnon
# #SouthCarolina
# #JISUNG
# #coronavirus
# #PasstheGlass
# #?????It
# #LNPCrimeFamily
# #JISUNG
# #ThanksObama
# #OhioPrimary
# #IDOL
# #KingTrump
# #corruption
# #VoterIDNow
# #BallotHarvesting.
# #ButcherOfBandra"
# #Pritzker
# #BOTD
# #BallotHarvesting.
# #coronavirus
# #coronavirus
# #50+
# #ThanksObama
# #JISUNG
# #CovidiotInChief
# #VoteByMail
# #coronavirus
# #Coronavirus
# #JoeBiden2020"
# #coronavirus
# #Labour
# #SiasaWednesday
# #BOTD
# #LabourLeadershipElection
# #BTS
# #WuhanVirus
# #SouthKorea
# #KingTrump
# #WeThePeople
# #Chomsky
# #coronavirus
# #JISUNG
# #LabourLeaks
# #THEBOYZ
# #,will
# #usa2020
# #Chomsky
# #Trump"
# #WuhanVirus
# #coronavirus
# #MAGA
# #SouthKorea
# #BangtanSlovakia
# #VoteByMail
# #Jeno
# #MichaelGove
# #?????
# #BTS
# #IndiaFightsCorona
# #Chomsky
# #25thamendment"
# #lkadvani##contest#election#ramayan
# #COVID19
# #BallotHarvesting.
# #OneVoice1
# #BallotHarvesting.
# #magavirus
# #JISUNG
# #VoterIDNow
# #Chomsky
# #Roblox
# #TyskySour,
# #COVID19sn
# #FakeDemocrat.
# #JISUNG
# #SmartNews
# #KoreanElection2020
# #BallotHarvesting.
# #QAlert
# #KoreanElection2020
# #coronavirus
# #COVID19
# #SouthCarolina
# #KoreanElection2020
# #MorningJoe"
# #moleg
# #VoteBidenToEndThisNightmare
# #WeAreTheNewsNow
# #Bernie
# #coronavirus
# #Norway,
# #21???????
# #QAlert
# #StopTheSteal
# #WednesdayThoughts
# #COVID19
# #FISA
# #PutThatInYourPipeHow
# #PeoplesParty
# #EmilieOldknow
# #???
# #FISA
# #Azerbaijan
# #FISA
# #WuhanVirus
# #PressRelease
# #YouClapForMeNow"
# #JISUNG
# #OnThisDay
# #gethelp
# #coronavirus
# #coronavirus
# #coronavirus
# #OneVoice1
# #WeAreTheNewsNow
# #TonightVMTV
# #StopTheSteal
# #Science
# #MAGA
# #VoterIDNow
# #Pritzker
# #FISA
# #abpoli
# #coronavirus
# #Jeez!
# #MAGA
# #coronavirus
# #Biafra
# #LabourHQ
# #JISUNG
# #Bernie
# #Biafra
# #LabourLeaks
# #BOTD
# #Chomsky
# #BallotHarvesting.
# #Chomsky
# #Biafra
# #BallotHarvesting.
# #BTS
# #IStandWithTaraReade
# #Biafra
# #BallotHarvesting.
# #????????_????
# #Biafra
# #BOTD
# #coronavirus
# #QAnon@realDonaldTrump
# #JISUNG
# #Norway,
# #OhioPrimary
# #BOTD
# #BallotHarvesting.
# #JoeBiden
# #coronavirus
# #ActOnClimate
# #Biafra
# #coronavirus
# #SickofTrump#COVID19
# #IDOL
# #WuhanVirus
# #coronavirus
# #TrumpPenceOutNow#OutNowhttps://t.co/64IDzcG0nf#GeneralStrike#GeneralStrike2020
# #moleg
# #COVID19
# #CA25
# #Biafra
# #QAnon
# #YangGang
# #CA25
# #VoterID2020
# #coronavirus
# #coronavirus
# #BTS
# #Biafra
# #coronavirusuk
# #EndiaWarHysteria1/3
# #QAnon
# #????????????????????????????
# #coronavirus
# #coronavirus
# #How2020CouldGetWorse
# #coronavirus
# #VotebyMail
# #HappyHMS
# #SouthCarolina
# #coronavirus
# #JISUNG
# #???
# #JISUNG
# #BTS
# #coronavirus
# #coronavirus
# #StopTheSteal
# #WednesdayThoughts
# #???
# #CA25
# #OneVoice1
# #coronavirus
# #ReopenAmerica
# #BallotHarvesting.
# #CA25
# #JISUNG
# #Biafra
# #JusticePrevailsThe
# #YangGang
# #coronavirus
# #JISUNG
# #OneVoice1
# #OneVoice1
# #ThanksObama
# #FISA
# #Biafra
# #Trump"
# #Chomsky
# #OneVoice1
# #TonightVMTV
# #coronavirus
# #????????_????
# #COVID19
# #Chomsky
# #BallotHarvesting.
# #auspol
# #coronavirus
# #coronavirus
# #EndiaWarHysteriaThe
# #Constitution
# #QAnon
# #coronavirus
# #RN
# #Ontario
# #voted
# #SouthCarolina
# #TDS
# #OneVoice1
# #BernieSanders
# #Pritzker
# #FISA
# #JISUNG
# #VigdisFinnbogadottir,
# #coronavirus
# #coronavirus
# #PeoplesParty
# #coronavirus
# #CongoFautEbonga"
# #BookertheBum
# #coronavirus
# #coronavirus
# #Epsteinhttps://t.co/Ul0jFrAnur"
# #QAnon
# #JISUNG
# #coronavirus
# #covid19
# #JISUNG
# #StopTheSteal
# #BTS
# #ThanksObama
# #WeThePeople
# #BallotHarvesting.
# #Starmergeddon
# #JISUNG
# #COVID19
# #OneVoice1
# #2020
# #WeThePeople
# #Yuju
# #Cuomo2024
# #Trump"
# #coronavirus
# #trump
# #BallotHarvesting.
# #coronavirus
# #JISUNG
# #coronavirus
# #ThanksObama
# #FreshElections
# #VotebyMail
# #BidenBeatsTrump
# #HongKong?s
# #climatedeniers
# #LNPCrimeFamily
# #KoreanElection2020"
# #ThanksObama
# #JoeBiden#MailinBallots#MailinVotingHow
# #BallotHarvesting.
# #ActOnClimate
# #BOTD
# #NUFCTakeover
# #crossfirehurricane.
# #JISUNG
# #DrainTheSwamp
# #Hoony
# #russiareport.
# #BTS
# #coronavirus
# #BernieOnTheBallot
# #BTS
# #YoonEunHye
# #makeamericaalaughingstockagain"
# #Trudeau
# #Biden2020
# #Appleton"
# #Chomsky
# #LabourLeaks
# #OneVoice1
# #Bernie
# #Yuju
# #BernThePrimary
# #KillerTories
# #nobodycares
# #SouthKorea
# #Democrat
# #Biden2020
# #SiasaWednesday
# #coronavoeus
# #InThisTogetherOhio
# #VoteByMail
# #TrueTheVote
# #LockHimUpNowSecure
# #covid19
# #Fascists
# #SUPERJUNIOR
# #FakeNewsMsM
# #BallotHarvesting.
# #JISUNG
# #Ethiopia
# #BallotHarvesting.
# #OneVoice1
# #1
# #Chomsky
# #Cameroon?s
# #BallotHarvesting.
# #Chomsky
# #Chomsky
# #Indy
# #2020election
# #JusticePrevailsThe
# #MAGA2020
# #COVID19
# #COVID19
# #WeThePeople
# #JISUNG
# #MAGA
# #How2020CouldGetWorse
# #Missinghome
# #????????????????????????????
# #,will
# #poweredxpeople
# #Yuju
# #NeverAgain
# #davidmurathe
# #coronavirus
# #coronavirus
# #OneVoice1
# #BhashanIsRation"
# #Azerbaijan
# #ElectionCommission
# #VoteByMail
# #VoterSuppression
# #415??
# #auspol
# #coronavirus
# #COVID19
# #VoterID
# #BangtanSlovakia
# #FreshElections
# #COVID19
# #ICYMI:
# #JISUNG
# #EndiaWarHysteriaThe
# #coronavirus
# #1.
# #Labour
# #ThanksObama
# #Trump
# #coronavirus
# #coronavirus
# #OneVoice1
# #endthelockdownnow
# #JISUNG
# #coronavirus
# #PMOPressConf:
# #StopTheSteal
# #SoundCloud
# #COVID19
# #MorningJoe
# #21???????
# #JISUNG
# #OneVoice1
# #SouthKorea
# #coronavirus
# #JoeBiden2020"
# #BOTD
# #JISUNG
# #ThanksObama
# #COVID19
# #BangtanSlovakia
# #Bitcoin
# #Biden2020
# #JISUNG
# #???????
# #coronavirus
# #ChennaiCorpRemoveRSS
# #OneVoice1
# #UNISON
# #BTS
# #QAnon
# #BallotHarvesting.
# #Yuju
# #RememberInNovember#VoteThemAllOut#VoteBlueToSaveAmericaExclusive:
# #JISUNG
# #RashidaTlaib,Vote
# #ThanksObama"
# #21???????
# #BallotHarvesting.
# #SUPERJUNIOR
# #Stimuluscheck
# #QAnon
# #coronavirus
# #Chomsky
# #coronavirus
# #C4News.
# #UnionYES
# #BTS
# #COVID19
# #Election
# #Bandra"
# #Yuju
# #Election
# #thread
# #Chomsky
# #ReopenAmerica??
# #BTS
# #JISUNG
# #IDOL
# #SheepNoMore
# #coronavirus
# #LNPCrimeFamily
# #coronavirus
# #coronavirus
# #poweredxpeople
# #coronavirus

# %% [markdown]
# ## Problem 2.2
#
# Modify your code in problem 2.1: this time instead of printing out the hashtag words, write and save them to an output text file. **Use your_last_name.txt as the name for the output txt file**.
# <br>**Note**: Make sure that each hashtag would appear in a separate line in the output file.

# %%
#open file
handle=open('Tweets.txt','r',encoding="utf-8")
outhandle=open('Eckerman.txt','w')
#read each line and find lines with #
for line in handle:
    if '#' in line:
        #find index number for each character and print between them
        beg=line.find('#')
        end=line.find(' ',beg)
        hashtag=line[beg:end]
        #put outut in a new file
        outhandle.write(hashtag+'\n')
outhandle.close()

# %% [markdown]
# ## Problem 3
#
# Write a python loop that goes through the following list of words, then for each word if it is longer than 4 characters, creates a new word out of that by concatenating the first two and the last two characters of it. Also, if the word length is 4 characters or less, print it out as is. Make sure that all output words are completely in lowercase letters.
# <br>words= ['Mobile','Good Morning','LAMP', 'Smart Things!', 'monty python', 'look']
#
# <br> the expected output:
# <br>mole
# <br>gong
# <br>lamp
# <br>sms!
# <br>moon
# <br>look

# %%
words= ['Mobile','Good Morning','LAMP', 'Smart Things!', 'monty python', 'look']
for word in words:
    length=len(word)
    word=word.lower()
    if length<=4:
        print(word)
    else:
        first=word[0:2]
        last=word[-2:]
        print(first+last)
# Out:
# mole
# gong
# lamp
# sms!
# moon
# look
